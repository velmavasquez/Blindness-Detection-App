# %%
import pandas as pd

# %%
path = 'data/train.csv'
df = pd.read_csv(path)
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df.loc[df['diagnosis'] == 4, 'diagnosis'] = 3
df
# Out:
#            id_code  diagnosis
# 0     000c1434d8d7          2
# 1     001639a390f0          3
# 2     0024cdab0c1e          1
# 3     002c21358ce6          0
# 4     005b95c28852          0
# 5     0083ee8054ee          3
# 6     0097f532ac9f          0
# 7     00a8624548a9          2
# 8     00b74780d31d          2
# 9     00cb6555d108          1
# 10    00cc2b75cddd          0
# 11    00e4ddff966a          2
# 12    00f6c1be5a33          0
# 13    0104b032c141          3
# 14    0124dffecf29          1
# 15    0125fbd2e791          0
# 16    012a242ac6ff          2
# 17    014508ccb9cb          0
# 18    0151781fe50b          0
# 19    0161338f53cc          2
# 20    0180bfa26c0b          2
# 21    0182152c50de          0
# 22    01b3aed3ed4c          1
# 23    01c7808d901d          2
# 24    01d9477b1171          0
# 25    01eb826f6467          2
# 26    01f7bb8be950          0
# 27    0212dd31f623          0
# 28    022f820027b8          0
# 29    0231642cf1c2          0
# ...

# %%
df.to_csv ('data/train_4category.csv', index = None, header=True)

# %%
df1 = pd.read_csv('data/train_4category.csv')
df1.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          3
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df.loc[df['diagnosis'] == 2].count()
# Out:
# id_code      999
# diagnosis    999
# dtype: int64

# %%
path = 'data/train.csv'
df1 = pd.read_csv(path)

df1.loc[df1['diagnosis'] == 3].count()
# Out:
# id_code      193
# diagnosis    193
# dtype: int64

# %%
df1.loc[df1['diagnosis'] == 4].count()
# Out:
# id_code      295
# diagnosis    295
# dtype: int64

# %%
df1.describe(include='all')
# Out:
#              id_code    diagnosis
# count           3662  3662.000000
# unique          3662          NaN
# top     874f8c1929f6          NaN
# freq               1          NaN
# mean             NaN     1.126980
# std              NaN     1.298409
# min              NaN     0.000000
# 25%              NaN     0.000000
# 50%              NaN     1.000000
# 75%              NaN     2.000000
# max              NaN     4.000000
